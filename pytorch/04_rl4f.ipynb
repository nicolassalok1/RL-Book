# %% [markdown]
# <img src="https://hilpisch.com/tpq_logo.png" alt="The Python Quants" width="35%" align="right" border="0"><br>

# %% [markdown]
# # Reinforcement Learning for Finance
#
# **Chapter 04 &mdash; Simulated Data**
#
# &copy; Dr. Yves J. Hilpisch
#
# <a href="https://tpq.io" target="_blank">https://tpq.io</a> | <a href="https://twitter.com/dyjh" target="_blank">@dyjh</a> | <a href="mailto:team@tpq.io">team@tpq.io</a>

# %% [markdown]
# ## Finance Environment

# %%
class ActionSpace:
    n = 2
    def sample(self):
        return random.randint(0, 1)

# %%
import numpy as np
import pandas as pd
from numpy.random import default_rng

# %%
rng = default_rng(seed=100)

# %%
class NoisyData:
    url = 'https://certificate.tpq.io/findata.csv'
    def __init__(self, symbol, feature, n_features=4,
                 min_accuracy=0.485, noise=True,
                 noise_std=0.001):
        self.symbol = symbol
        self.feature = feature
        self.n_features = n_features
        self.noise = noise
        self.noise_std = noise_std
        self.action_space = ActionSpace()
        self.min_accuracy = min_accuracy
        self._get_data()
        self._prepare_data()
    def _get_data(self):
        self.raw = pd.read_csv(self.url,
                index_col=0, parse_dates=True)

# %%
class NoisyData(NoisyData):
    def _prepare_data(self):
        self.data = pd.DataFrame(self.raw[self.symbol]).dropna()
        if self.noise:
            std = self.data.mean() * self.noise_std
            self.data[self.symbol] = (self.data[self.symbol] +
                rng.normal(0, std, len(self.data)))
        self.data['r'] = np.log(self.data / self.data.shift(1))
        self.data['d'] = np.where(self.data['r'] > 0, 1, 0)
        self.data.dropna(inplace=True)
        ma, mi = self.data.max(), self.data.min()
        self.data_ = (self.data - mi) / (ma - mi)
    def reset(self):
        if self.noise:
            self._prepare_data()
        self.bar = self.n_features
        self.treward = 0
        state = self.data_[self.feature].iloc[
            self.bar - self.n_features:self.bar].values
        return state, {}

# %%
class NoisyData(NoisyData):
    def step(self, action):
        if action == self.data['d'].iloc[self.bar]:
            correct = True
        else:
            correct = False
        reward = 1 if correct else 0 
        self.treward += reward
        self.bar += 1
        self.accuracy = self.treward / (self.bar - self.n_features)
        if self.bar >= len(self.data):
            done = True
        elif reward == 1:
            done = False
        elif (self.accuracy < self.min_accuracy and
              self.bar > self.n_features + 15):
            done = True
        else:
            done = False
        next_state = self.data_[self.feature].iloc[
            self.bar - self.n_features:self.bar].values
        return next_state, reward, done, False, {}

# %%
fin = NoisyData(symbol='EUR=', feature='EUR=',
                noise=True, noise_std=0.005)

# %%
fin.reset()
# Out:
# (array([0.79295659, 0.81097879, 0.78840972, 0.80597193]), {})

# %%
fin.reset()
# Out:
# (array([0.80642276, 0.77840938, 0.80096369, 0.76938581]), {})

# %%
fin = NoisyData('EUR=', 'r', n_features=4,
                noise=True, noise_std=0.005)

# %%
fin.reset()
# Out:
# (array([0.54198375, 0.30674865, 0.45688528, 0.52884033]), {})

# %%
fin.reset()
# Out:
# (array([0.37967631, 0.40190291, 0.49196183, 0.47536065]), {})

# %%
from pylab import plt, mpl
plt.style.use('seaborn-v0_8')
mpl.rcParams['figure.dpi'] = 300
mpl.rcParams['savefig.dpi'] = 300
mpl.rcParams['font.family'] = 'serif'

# %%
import warnings
warnings.simplefilter('ignore')

# %%
for _ in range(5):
    fin.reset()
    fin.data[fin.symbol].loc['2022-7-1':].plot(lw=0.75, c='b')

# %%
# %run dqlagent_pytorch.py

# %%
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

# %%
from dqlagent_pytorch import DQLAgent

agent = DQLAgent(fin.symbol, fin.feature, fin.n_features, fin)

# %%
# %time agent.learn(50)
# Out:
# episode=   1 | treward= 22.000 | max= 22.000
# episode=   2 | treward=  7.000 | max= 22.000
# episode=   3 | treward=  8.000 | max= 22.000
# episode=   4 | treward=896.000 | max=896.000
# episode=   5 | treward=  4.000 | max=896.000
# episode=   6 | treward= 11.000 | max=896.000
# episode=   7 | treward=1332.000 | max=1332.000
# episode=   8 | treward=  6.000 | max=1332.000
# episode=   9 | treward= 90.000 | max=1332.000
# episode=  10 | treward=  8.000 | max=1332.000
# episode=  11 | treward= 41.000 | max=1332.000
# episode=  12 | treward=  5.000 | max=1332.000
# episode=  13 | treward=  7.000 | max=1332.000
# episode=  14 | treward=  6.000 | max=1332.000
# episode=  15 | treward=  8.000 | max=1332.000
# episode=  16 | treward=  5.000 | max=1332.000
# episode=  17 | treward= 10.000 | max=1332.000
# episode=  18 | treward=  5.000 | max=1332.000
# episode=  19 | treward=  6.000 | max=1332.000
# episode=  20 | treward= 10.000 | max=1332.000
# episode=  21 | treward=  3.000 | max=1332.000
# episode=  22 | treward= 25.000 | max=1332.000
# episode=  23 | treward=1335.000 | max=1335.000
# episode=  24 | treward=1314.000 | max=1335.000
# episode=  25 | treward=  6.000 | max=1335.000
# episode=  26 | treward=  8.000 | max=1335.000
# episode=  27 | treward=1339.000 | max=1339.000
# episode=  28 | treward=  7.000 | max=1339.000
# episode=  29 | treward= 10.000 | max=1339.000
# episode=  30 | treward=  8.000 | max=1339.000
# episode=  31 | treward=  9.000 | max=1339.000
# episode=  32 | treward= 11.000 | max=1339.000
# episode=  33 | treward= 10.000 | max=1339.000
# episode=  34 | treward= 32.000 | max=1339.000
# episode=  35 | treward=1352.000 | max=1352.000
# episode=  36 | treward=  6.000 | max=1352.000
# episode=  37 | treward=1336.000 | max=1352.000
# episode=  38 | treward= 12.000 | max=1352.000
# episode=  39 | treward=  7.000 | max=1352.000
# episode=  40 | treward=  9.000 | max=1352.000
# episode=  41 | treward=  7.000 | max=1352.000
# episode=  42 | treward=  6.000 | max=1352.000
# episode=  43 | treward=  9.000 | max=1352.000
# episode=  44 | treward=  7.000 | max=1352.000
# episode=  45 | treward=  6.000 | max=1352.000
# episode=  46 | treward=  5.000 | max=1352.000
# episode=  47 | treward= 11.000 | max=1352.000
# episode=  48 | treward= 20.000 | max=1352.000
# episode=  49 | treward=1272.000 | max=1352.000
# episode=  50 | treward=  6.000 | max=1352.000
# CPU times: total: 1.7 s
# Wall time: 2.24 s

# %%
agent.test(5)
# Out:
# total reward=2604 | accuracy=0.500
# total reward=2604 | accuracy=0.508
# total reward=2604 | accuracy=0.510
# total reward=2604 | accuracy=0.501
# total reward=2604 | accuracy=0.525

# %%
class Simulation:
    def __init__(self, symbol, feature, n_features,
                 start, end, periods,
                 min_accuracy=0.525, x0=100,
                 kappa=1, theta=100, sigma=0.2,
                 normalize=True, new=False):
        self.symbol = symbol
        self.feature = feature
        self.n_features = n_features
        self.start = start
        self.end = end
        self.periods = periods
        self.x0 = x0
        self.kappa = kappa
        self.theta = theta
        self.sigma = sigma
        self.min_accuracy = min_accuracy
        self.normalize = normalize
        self.new = new
        self.action_space = ActionSpace()
        self._simulate_data()
        self._prepare_data()

# %%
import math
class Simulation(Simulation):
    def _simulate_data(self):
        index = pd.date_range(start=self.start,
                    end=self.end, periods=self.periods)
        x = [self.x0]
        dt = (index[-1] - index[0]).days / 365 / self.periods
        for t in range(1, len(index)):
            x_ = (x[t - 1] + self.kappa * (self.theta - x[t - 1]) * dt +
                  x[t - 1] * self.sigma * math.sqrt(dt) *
                  random.gauss(0, 1))
            x.append(x_)
        
        self.data = pd.DataFrame(x, columns=[self.symbol], index=index)

# %%
class Simulation(Simulation):
    def _prepare_data(self):
        self.data['r'] = np.log(self.data / self.data.shift(1))
        self.data.dropna(inplace=True)
        if self.normalize:
            self.mu = self.data.mean()
            self.std = self.data.std()
            self.data_ = (self.data - self.mu) / self.std
        else:
            self.data_ = self.data.copy()
        self.data['d'] = np.where(self.data['r'] > 0, 1, 0)
        self.data['d'] = self.data['d'].astype(int)

# %%
class Simulation(Simulation):
    def _get_state(self):
        return self.data_[self.feature].iloc[self.bar -
                                self.n_features:self.bar]
    def seed(self, seed):
        random.seed(seed)
    def reset(self):
        self.treward = 0
        self.accuracy = 0
        self.bar = self.n_features
        if self.new:
            self._simulate_data()
            self._prepare_data()
        state = self._get_state()
        return state.values, {}

# %%
class Simulation(Simulation):
    def step(self, action):
        if action == self.data['d'].iloc[self.bar]:
            correct = True
        else:
            correct = False
        reward = 1 if correct else 0 
        self.treward += reward
        self.bar += 1
        self.accuracy = self.treward / (self.bar - self.n_features)
        if self.bar >= len(self.data):
            done = True
        elif reward == 1:
            done = False
        elif (self.accuracy < self.min_accuracy and self.bar > 25):
            done = True
        else:
            done = False
        next_state = self.data_[self.feature].iloc[
            self.bar - self.n_features:self.bar].values
        return next_state, reward, done, False, {}

# %%
sym = 'EUR='

# %%
env_base = Simulation(sym, sym, 5, start='2024-1-1', end='2025-1-1',
                 periods=252, x0=1, kappa=1, theta=1.1, sigma=0.0,
                 normalize=True)

# %%
env_trend = Simulation(sym, sym, 5, start='2024-1-1', end='2025-1-1',
                 periods=252, x0=1, kappa=1, theta=2, sigma=0.1,
                 normalize=True)

# %%
env_mrev = Simulation(sym, sym, 5, start='2024-1-1', end='2025-1-1',
                 periods=252, x0=1, kappa=1, theta=1, sigma=0.1,
                 normalize=True)

# %%
env_mrev.data[sym].iloc[:3]
# Out:
# 2024-01-02 10:59:45.657370517    1.003837
# 2024-01-03 21:59:31.314741035    1.007183
# 2024-01-05 08:59:16.972111553    1.012571
# Name: EUR=, dtype: float64

# %%
env_base.data[sym].plot(figsize=(10, 6), label='baseline', style='r')
env_trend.data[sym].plot(label='trend', style='b:')
env_mrev.data[sym].plot(label='mean-reversion', style='g--')
plt.legend();

# %%
sim = Simulation(sym, 'r', 4, start='2024-1-1', end='2028-1-1',
                 periods=2 * 252, min_accuracy=0.485, x0=1,
                 kappa=2, theta=2, sigma=0.15,
                 normalize=True, new=True)
sim.seed(100)

# %%
for _ in range(10):
    sim.reset()
    sim.data[sym].plot(figsize=(10, 6), lw=1.0, c='b');

# %%
agent = DQLAgent(sim.symbol, sim.feature,
                 sim.n_features, sim, lr=0.0001)

# %%
# %time agent.learn(50)
# Out:
# episode=   1 | treward= 13.000 | max= 13.000
# episode=   2 | treward=  8.000 | max= 13.000
# episode=   3 | treward= 38.000 | max= 38.000
# episode=   4 | treward=273.000 | max=273.000
# episode=   5 | treward= 10.000 | max=273.000
# episode=   6 | treward= 10.000 | max=273.000
# episode=   7 | treward=261.000 | max=273.000
# episode=   8 | treward= 12.000 | max=273.000
# episode=   9 | treward= 11.000 | max=273.000
# episode=  10 | treward= 11.000 | max=273.000
# episode=  11 | treward=  7.000 | max=273.000
# episode=  12 | treward= 10.000 | max=273.000
# episode=  13 | treward= 15.000 | max=273.000
# episode=  14 | treward= 16.000 | max=273.000
# episode=  15 | treward=255.000 | max=273.000
# episode=  16 | treward=  9.000 | max=273.000
# episode=  17 | treward=244.000 | max=273.000
# episode=  18 | treward= 10.000 | max=273.000
# episode=  19 | treward=  7.000 | max=273.000
# episode=  20 | treward= 12.000 | max=273.000
# episode=  21 | treward= 11.000 | max=273.000
# episode=  22 | treward=  9.000 | max=273.000
# episode=  23 | treward=  7.000 | max=273.000
# episode=  24 | treward= 10.000 | max=273.000
# episode=  25 | treward=  9.000 | max=273.000
# episode=  26 | treward=  9.000 | max=273.000
# episode=  27 | treward=  9.000 | max=273.000
# episode=  28 | treward= 10.000 | max=273.000
# episode=  29 | treward= 58.000 | max=273.000
# episode=  30 | treward= 11.000 | max=273.000
# episode=  31 | treward= 19.000 | max=273.000
# episode=  32 | treward= 13.000 | max=273.000
# episode=  33 | treward= 28.000 | max=273.000
# episode=  34 | treward= 12.000 | max=273.000
# episode=  35 | treward=  8.000 | max=273.000
# episode=  36 | treward= 15.000 | max=273.000
# episode=  37 | treward=  8.000 | max=273.000
# episode=  38 | treward=  8.000 | max=273.000
# episode=  39 | treward=  5.000 | max=273.000
# episode=  40 | treward= 28.000 | max=273.000
# episode=  41 | treward= 16.000 | max=273.000
# episode=  42 | treward= 12.000 | max=273.000
# episode=  43 | treward= 62.000 | max=273.000
# episode=  44 | treward= 13.000 | max=273.000
# episode=  45 | treward= 15.000 | max=273.000
# episode=  46 | treward=  8.000 | max=273.000
# episode=  47 | treward= 12.000 | max=273.000
# episode=  48 | treward=264.000 | max=273.000
# episode=  49 | treward= 11.000 | max=273.000
# episode=  50 | treward=  8.000 | max=273.000
# CPU times: total: 562 ms
# Wall time: 586 ms

# %%
agent.test(5)
# Out:
# total reward= 499 | accuracy=0.523
# total reward= 499 | accuracy=0.483
# total reward= 499 | accuracy=0.477
# total reward= 499 | accuracy=0.485
# total reward= 499 | accuracy=0.455

# %%
sim = Simulation(sym, 'r', 4, start='2024-1-1', end='2028-1-1',
                 periods=2 * 252, min_accuracy=0.6, x0=1,
                 kappa=1.25, theta=1, sigma=0.15,
                 normalize=True, new=True)
sim.seed(100)

# %%
agent = DQLAgent(sim.symbol, sim.feature,
                 sim.n_features, sim, lr=0.0001)

# %%
# %time agent.learn(150)
# Out:
# episode=   1 | treward= 12.000 | max= 12.000
# episode=   2 | treward= 16.000 | max= 16.000
# episode=   3 | treward= 10.000 | max= 16.000
# episode=   4 | treward= 12.000 | max= 16.000
# episode=   5 | treward= 11.000 | max= 16.000
# episode=   6 | treward=  9.000 | max= 16.000
# episode=   7 | treward= 14.000 | max= 16.000
# episode=   8 | treward= 12.000 | max= 16.000
# episode=   9 | treward= 11.000 | max= 16.000
# episode=  10 | treward= 11.000 | max= 16.000
# episode=  11 | treward= 10.000 | max= 16.000
# episode=  12 | treward= 11.000 | max= 16.000
# episode=  13 | treward= 10.000 | max= 16.000
# episode=  14 | treward= 11.000 | max= 16.000
# episode=  15 | treward= 11.000 | max= 16.000
# episode=  16 | treward= 19.000 | max= 19.000
# episode=  17 | treward= 17.000 | max= 19.000
# episode=  18 | treward= 14.000 | max= 19.000
# episode=  19 | treward= 14.000 | max= 19.000
# episode=  20 | treward= 10.000 | max= 19.000
# episode=  21 | treward= 13.000 | max= 19.000
# episode=  22 | treward= 18.000 | max= 19.000
# episode=  23 | treward=  8.000 | max= 19.000
# episode=  24 | treward= 13.000 | max= 19.000
# episode=  25 | treward= 13.000 | max= 19.000
# episode=  26 | treward= 13.000 | max= 19.000
# episode=  27 | treward= 20.000 | max= 20.000
# episode=  28 | treward=  9.000 | max= 20.000
# episode=  29 | treward=  9.000 | max= 20.000
# episode=  30 | treward= 10.000 | max= 20.000
# episode=  31 | treward= 13.000 | max= 20.000
# episode=  32 | treward= 30.000 | max= 30.000
# episode=  33 | treward= 10.000 | max= 30.000
# episode=  34 | treward= 10.000 | max= 30.000
# episode=  35 | treward= 18.000 | max= 30.000
# episode=  36 | treward=  7.000 | max= 30.000
# episode=  37 | treward= 11.000 | max= 30.000
# episode=  38 | treward=  9.000 | max= 30.000
# episode=  39 | treward= 14.000 | max= 30.000
# episode=  40 | treward= 13.000 | max= 30.000
# episode=  41 | treward=  8.000 | max= 30.000
# episode=  42 | treward=  9.000 | max= 30.000
# episode=  43 | treward= 14.000 | max= 30.000
# episode=  44 | treward= 18.000 | max= 30.000
# episode=  45 | treward= 16.000 | max= 30.000
# episode=  46 | treward= 11.000 | max= 30.000
# episode=  47 | treward=  9.000 | max= 30.000
# episode=  48 | treward=  7.000 | max= 30.000
# episode=  49 | treward=  8.000 | max= 30.000
# episode=  50 | treward=  9.000 | max= 30.000
# episode=  51 | treward= 11.000 | max= 30.000
# episode=  52 | treward= 14.000 | max= 30.000
# episode=  53 | treward=  9.000 | max= 30.000
# episode=  54 | treward= 10.000 | max= 30.000
# episode=  55 | treward= 28.000 | max= 30.000
# episode=  56 | treward= 11.000 | max= 30.000
# episode=  57 | treward= 10.000 | max= 30.000
# episode=  58 | treward=  6.000 | max= 30.000
# episode=  59 | treward=  9.000 | max= 30.000
# episode=  60 | treward= 10.000 | max= 30.000
# episode=  61 | treward= 12.000 | max= 30.000
# episode=  62 | treward=  9.000 | max= 30.000
# episode=  63 | treward= 13.000 | max= 30.000
# episode=  64 | treward= 14.000 | max= 30.000
# episode=  65 | treward= 10.000 | max= 30.000
# episode=  66 | treward= 10.000 | max= 30.000
# episode=  67 | treward= 11.000 | max= 30.000
# episode=  68 | treward= 11.000 | max= 30.000
# episode=  69 | treward= 13.000 | max= 30.000
# episode=  70 | treward=  9.000 | max= 30.000
# episode=  71 | treward= 10.000 | max= 30.000
# episode=  72 | treward= 22.000 | max= 30.000
# episode=  73 | treward= 10.000 | max= 30.000
# episode=  74 | treward= 10.000 | max= 30.000
# episode=  75 | treward= 11.000 | max= 30.000
# episode=  76 | treward=  9.000 | max= 30.000
# episode=  77 | treward=  8.000 | max= 30.000
# episode=  78 | treward= 11.000 | max= 30.000
# episode=  79 | treward= 19.000 | max= 30.000
# episode=  80 | treward= 13.000 | max= 30.000
# episode=  81 | treward= 29.000 | max= 30.000
# episode=  82 | treward= 12.000 | max= 30.000
# episode=  83 | treward= 14.000 | max= 30.000
# episode=  84 | treward=  8.000 | max= 30.000
# episode=  85 | treward= 11.000 | max= 30.000
# episode=  86 | treward= 19.000 | max= 30.000
# episode=  87 | treward=  7.000 | max= 30.000
# episode=  88 | treward= 16.000 | max= 30.000
# episode=  89 | treward=  5.000 | max= 30.000
# episode=  90 | treward= 10.000 | max= 30.000
# episode=  91 | treward= 11.000 | max= 30.000
# episode=  92 | treward= 11.000 | max= 30.000
# episode=  93 | treward= 10.000 | max= 30.000
# episode=  94 | treward=  7.000 | max= 30.000
# episode=  95 | treward=  7.000 | max= 30.000
# episode=  96 | treward=  8.000 | max= 30.000
# episode=  97 | treward=  9.000 | max= 30.000
# episode=  98 | treward= 11.000 | max= 30.000
# episode=  99 | treward= 13.000 | max= 30.000
# episode= 100 | treward= 11.000 | max= 30.000
# episode= 101 | treward= 11.000 | max= 30.000
# episode= 102 | treward= 17.000 | max= 30.000
# episode= 103 | treward=  8.000 | max= 30.000
# episode= 104 | treward= 12.000 | max= 30.000
# episode= 105 | treward= 34.000 | max= 34.000
# episode= 106 | treward=  9.000 | max= 34.000
# episode= 107 | treward= 12.000 | max= 34.000
# episode= 108 | treward= 12.000 | max= 34.000
# episode= 109 | treward= 13.000 | max= 34.000
# episode= 110 | treward= 10.000 | max= 34.000
# episode= 111 | treward=  7.000 | max= 34.000
# episode= 112 | treward= 13.000 | max= 34.000
# episode= 113 | treward= 10.000 | max= 34.000
# episode= 114 | treward= 11.000 | max= 34.000
# episode= 115 | treward= 12.000 | max= 34.000
# episode= 116 | treward= 31.000 | max= 34.000
# episode= 117 | treward= 11.000 | max= 34.000
# episode= 118 | treward= 13.000 | max= 34.000
# episode= 119 | treward= 12.000 | max= 34.000
# episode= 120 | treward= 12.000 | max= 34.000
# episode= 121 | treward= 11.000 | max= 34.000
# episode= 122 | treward= 23.000 | max= 34.000
# episode= 123 | treward= 36.000 | max= 36.000
# episode= 124 | treward= 15.000 | max= 36.000
# episode= 125 | treward= 12.000 | max= 36.000
# episode= 126 | treward= 19.000 | max= 36.000
# episode= 127 | treward= 16.000 | max= 36.000
# episode= 128 | treward=  9.000 | max= 36.000
# episode= 129 | treward=  5.000 | max= 36.000
# episode= 130 | treward= 10.000 | max= 36.000
# episode= 131 | treward=  8.000 | max= 36.000
# episode= 132 | treward=  9.000 | max= 36.000
# episode= 133 | treward=  9.000 | max= 36.000
# episode= 134 | treward=  9.000 | max= 36.000
# episode= 135 | treward= 16.000 | max= 36.000
# episode= 136 | treward= 17.000 | max= 36.000
# episode= 137 | treward= 10.000 | max= 36.000
# episode= 138 | treward= 15.000 | max= 36.000
# episode= 139 | treward=  7.000 | max= 36.000
# episode= 140 | treward=  9.000 | max= 36.000
# episode= 141 | treward= 13.000 | max= 36.000
# episode= 142 | treward= 13.000 | max= 36.000
# episode= 143 | treward= 16.000 | max= 36.000
# episode= 144 | treward= 16.000 | max= 36.000
# episode= 145 | treward= 11.000 | max= 36.000
# episode= 146 | treward= 10.000 | max= 36.000
# episode= 147 | treward= 20.000 | max= 36.000
# episode= 148 | treward= 10.000 | max= 36.000
# episode= 149 | treward= 11.000 | max= 36.000
# episode= 150 | treward= 19.000 | max= 36.000
# CPU times: total: 1.16 s
# Wall time: 1.27 s

# %%
agent.test(5)
# Out:
# total reward= 499 | accuracy=0.535
# total reward= 499 | accuracy=0.495
# total reward= 499 | accuracy=0.523
# total reward= 499 | accuracy=0.537
# total reward= 499 | accuracy=0.457

# %% [markdown]
# <img src="https://hilpisch.com/tpq_logo.png" alt="The Python Quants" width="35%" align="right" border="0"><br>
#
# <a href="https://tpq.io" target="_blank">https://tpq.io</a> | <a href="https://twitter.com/dyjh" target="_blank">@dyjh</a> | <a href="mailto:team@tpq.io">team@tpq.io</a>
